# %% [markdown]
# # Creating a random forest predictor for Eliteserien matches with pandas and sklearn

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, accuracy_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# We will use the csv file we created with scraping.ipynb

# %%
matches = pd.read_csv("matches.csv", index_col =0)
matches.head
# Out:
# <bound method NDFrame.head of           date   time         comp         round  day venue result gf ga  \
# 0   2023-04-10  17:00  Eliteserien   Matchweek 1  Mon  Away      W  2  0
# 1   2023-04-16  17:00  Eliteserien   Matchweek 2  Sun  Home      W  4  0
# 2   2023-04-23  17:00  Eliteserien   Matchweek 3  Sun  Away      W  3  0
# 3   2023-04-29  18:00  Eliteserien   Matchweek 4  Sat  Home      D  2  2
# 4   2023-05-03  18:00  Eliteserien  Matchweek 18  Wed  Home      W  2  0
# ..         ...    ...          ...           ...  ...   ...    ... .. ..
# 25  2021-11-07  17:00  Eliteserien  Matchweek 26  Sun  Home      L  0  1
# 26  2021-11-20  18:00  Eliteserien  Matchweek 27  Sat  Away      W  2  1
# 27  2021-11-28  17:00  Eliteserien  Matchweek 28  Sun  Home      L  1  3
# 28  2021-12-05  17:00  Eliteserien  Matchweek 29  Sun  Away      L  0  2
# 29  2021-12-12  17:00  Eliteserien  Matchweek 30  Sun  Home      L  0  3
#
#         opponent  ...            referee  match report notes    sh  sot dist  \
# 0   Sarpsborg 08  ...         Ola Nilsen  Match Report   NaN  18.0  7.0  NaN
# 1         Stabæk  ...      Marius Grøtta  Match Report   NaN  19.0  7.0  NaN
# 2       Aalesund  ...     Mohammad Aslam  Match Report   NaN  20.0  6.0  NaN
# 3          Brann  ...  Svein Oddvar Moen  Match Report   NaN  15.0  5.0  NaN
# 4            Odd  ...      Sivert Amland  Match Report   NaN   7.0  3.0  NaN
# ..           ...  ...                ...           ...   ...   ...  ...  ...
# 25        Viking  ...   Sigurd Kringstad  Match Report   NaN   9.0  2.0  NaN
# 26  Strømsgodset  ...          Tom Hagen  Match Report   NaN   4.0  2.0  NaN
# 27  Sarpsborg 08  ...  Svein Oddvar Moen  Match Report   NaN  14.0  5.0  NaN
# 28     Vålerenga  ...        Tore Hansen  Match Report   NaN   9.0  6.0  NaN
# 29    Bodø/Glimt  ...          Tom Hagen  Match Report   NaN   4.0  1.0  NaN
#
#    pk  pkatt  season       team
# 0   0      0    2023  BodoGlimt
# 1   0      1    2023  BodoGlimt
# 2   0      0    2023  BodoGlimt
# 3   0      0    2023  BodoGlimt
# 4   0      0    2023  BodoGlimt
# .. ..    ...     ...        ...
# 25  0      1    2021  Mjondalen
# 26  0      0    2021  Mjondalen
# 27  0      0    2021  Mjondalen
# 28  0      0    2021  Mjondalen
# 29  0      0    2021  Mjondalen
#
# [1443 rows x 24 columns]>

# %%
matches.shape
# Out:
# (1443, 24)

# %% [markdown]
# Sandefjord and Brann have a different amount of matches than what we would expect

# %%
matches["team"].value_counts()
# Out:
# team
# Sandefjord      92
# Tromso          90
# BodoGlimt       90
# Valerenga       90
# Viking          90
# Lillestrom      90
# Molde           90
# Sarpsborg 08    90
# Rosenborg       90
# Odd             90
# Stromsgodset    90
# Haugesund       90
# Brann           61
# HamKam          60
# Stabaek         60
# Aalesund        60
# Kristiansund    60
# Jerv            30
# Mjondalen       30
# Name: count, dtype: int64

# %% [markdown]
# It seems the Eliteserien playoff matches have been included when we scraped the data.

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1                                     48
# Matchweek 2                                     48
# Matchweek 3                                     48
# Matchweek 4                                     48
# Matchweek 18                                    48
# Matchweek 5                                     48
# Matchweek 6                                     48
# Matchweek 7                                     48
# Matchweek 8                                     48
# Matchweek 9                                     48
# Matchweek 10                                    48
# Matchweek 11                                    48
# Matchweek 12                                    48
# Matchweek 13                                    48
# Matchweek 14                                    48
# Matchweek 15                                    48
# Matchweek 16                                    48
# Matchweek 17                                    48
# Matchweek 19                                    48
# Matchweek 21                                    48
# Matchweek 22                                    48
# Matchweek 23                                    48
# Matchweek 20                                    48
# Matchweek 24                                    48
# Matchweek 25                                    48
# Matchweek 26                                    48
# Matchweek 27                                    48
# Matchweek 28                                    48
# Matchweek 29                                    48
# Matchweek 30                                    48
# Norwegian 1/2 Relegation/Promotion Play-offs     3
# Name: count, dtype: int64

# %% [markdown]
# We fix this by specifying that only the rows where the column "comp" is "Eliteserien" is included in matches.

# %%
matches = matches[matches.comp == "Eliteserien"]

# %%
matches["team"].value_counts()
# Out:
# team
# BodoGlimt       90
# Tromso          90
# Viking          90
# Valerenga       90
# Molde           90
# Lillestrom      90
# Stromsgodset    90
# Sarpsborg 08    90
# Rosenborg       90
# Odd             90
# Haugesund       90
# Sandefjord      90
# Brann           60
# HamKam          60
# Stabaek         60
# Aalesund        60
# Kristiansund    60
# Jerv            30
# Mjondalen       30
# Name: count, dtype: int64

# %% [markdown]
# Some of the variables are an object type, which we can not use with the algorithm we are using.

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf               object
# ga               object
# opponent         object
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes            object
# sh              float64
# sot             float64
# dist            float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %% [markdown]
# We change the "date" from a object type to datetime. We convert the venue and opponent into integers and create new columns for these variables. We also create an "hour" column which turns the "time" column into integers and only keeps the first two numbers (17:30 to 17), and we also create a "day_code" column with integer values for each day of the week. The final column we will add is a "target column", and for this project we only care whether a team has won or not, so if the result is a draw or a loss the value will be 0 and if the team won the value will be 1.

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time         comp         round  day venue result gf ga  \
# 0  2023-04-10  17:00  Eliteserien   Matchweek 1  Mon  Away      W  2  0
# 1  2023-04-16  17:00  Eliteserien   Matchweek 2  Sun  Home      W  4  0
# 2  2023-04-23  17:00  Eliteserien   Matchweek 3  Sun  Away      W  3  0
# 3  2023-04-29  18:00  Eliteserien   Matchweek 4  Sat  Home      D  2  2
# 4  2023-05-03  18:00  Eliteserien  Matchweek 18  Wed  Home      W  2  0
# ..        ...    ...          ...           ...  ...   ...    ... .. ..
# 25 2021-11-07  17:00  Eliteserien  Matchweek 26  Sun  Home      L  0  1
# 26 2021-11-20  18:00  Eliteserien  Matchweek 27  Sat  Away      W  2  1
# 27 2021-11-28  17:00  Eliteserien  Matchweek 28  Sun  Home      L  1  3
# 28 2021-12-05  17:00  Eliteserien  Matchweek 29  Sun  Away      L  0  2
# 29 2021-12-12  17:00  Eliteserien  Matchweek 30  Sun  Home      L  0  3
#
#         opponent  ...  dist  pk pkatt season       team venue_code opp_code  \
# 0   Sarpsborg 08  ...   NaN   0     0   2023  BodoGlimt          0       13
# 1         Stabæk  ...   NaN   0     1   2023  BodoGlimt          1       14
# 2       Aalesund  ...   NaN   0     0   2023  BodoGlimt          0        0
# 3          Brann  ...   NaN   0     0   2023  BodoGlimt          1        2
# 4            Odd  ...   NaN   0     0   2023  BodoGlimt          1       10
# ..           ...  ...   ...  ..   ...    ...        ...        ...      ...
# 25        Viking  ...   NaN   0     1   2021  Mjondalen          1       17
# 26  Strømsgodset  ...   NaN   0     0   2021  Mjondalen          0       15
# 27  Sarpsborg 08  ...   NaN   0     0   2021  Mjondalen          1       13
# 28     Vålerenga  ...   NaN   0     0   2021  Mjondalen          0       18
# 29    Bodø/Glimt  ...   NaN   0     0   2021  Mjondalen          1        1
#
#     hour  day_code  target
# 0     17         0       1
# 1     17         6       1
# 2     17         6       1
# 3     18         5       0
# 4     18         2       1
# ..   ...       ...     ...
# 25    17         6       0
# 26    18         5       1
# 27    17         6       0
# 28    17         6       0
# 29    17         6       0
#
# [1440 rows x 29 columns]

# %% [markdown]
# We initiate the random forest classifier with 50 individual decision trees, 10 samples in a leaf of the decision tree before we split the node, and random state set to 1 som that we will get the same result every time as long as we give the model the same data.

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %% [markdown]
# As this is time-series data, it is important that we use the oldest data as training and the newest as test, as we cant use future information to predict the past. We use the 2023 season as test and everything before 2023 as train.

# %%
train = matches[matches["date"] < "2023-01-01"]
train
# Out:
#          date   time         comp         round  day venue result gf ga  \
# 0  2022-04-02  18:00  Eliteserien   Matchweek 1  Sat  Home      W  1  0
# 1  2022-04-10  18:00  Eliteserien   Matchweek 2  Sun  Away      W  3  1
# 2  2022-04-18  18:00  Eliteserien   Matchweek 3  Mon  Home      L  1  2
# 3  2022-04-24  20:00  Eliteserien   Matchweek 4  Sun  Away      D  0  0
# 4  2022-05-07  18:00  Eliteserien   Matchweek 5  Sat  Home      L  3  4
# ..        ...    ...          ...           ...  ...   ...    ... .. ..
# 25 2021-11-07  17:00  Eliteserien  Matchweek 26  Sun  Home      L  0  1
# 26 2021-11-20  18:00  Eliteserien  Matchweek 27  Sat  Away      W  2  1
# 27 2021-11-28  17:00  Eliteserien  Matchweek 28  Sun  Home      L  1  3
# 28 2021-12-05  17:00  Eliteserien  Matchweek 29  Sun  Away      L  0  2
# 29 2021-12-12  17:00  Eliteserien  Matchweek 30  Sun  Home      L  0  3
#
#         opponent  ...  dist  pk pkatt season       team venue_code opp_code  \
# 0      Vålerenga  ...   NaN   0     0   2022      Molde          1       18
# 1   Strømsgodset  ...   NaN   0     0   2022      Molde          0       15
# 2     Lillestrøm  ...   NaN   0     0   2022      Molde          1        7
# 3      Rosenborg  ...   NaN   0     0   2022      Molde          0       11
# 4         Viking  ...   NaN   0     0   2022      Molde          1       17
# ..           ...  ...   ...  ..   ...    ...        ...        ...      ...
# 25        Viking  ...   NaN   0     1   2021  Mjondalen          1       17
# 26  Strømsgodset  ...   NaN   0     0   2021  Mjondalen          0       15
# 27  Sarpsborg 08  ...   NaN   0     0   2021  Mjondalen          1       13
# 28     Vålerenga  ...   NaN   0     0   2021  Mjondalen          0       18
# 29    Bodø/Glimt  ...   NaN   0     0   2021  Mjondalen          1        1
#
#     hour  day_code  target
# 0     18         5       1
# 1     18         6       1
# 2     18         0       0
# 3     20         6       0
# 4     18         5       0
# ..   ...       ...     ...
# 25    17         6       0
# 26    18         5       1
# 27    17         6       0
# 28    17         6       0
# 29    17         6       0
#
# [960 rows x 29 columns]

# %%
test = matches[matches["date"] > "2023-01-01"]
test
# Out:
#          date   time         comp         round  day venue result gf ga  \
# 0  2023-04-10  17:00  Eliteserien   Matchweek 1  Mon  Away      W  2  0
# 1  2023-04-16  17:00  Eliteserien   Matchweek 2  Sun  Home      W  4  0
# 2  2023-04-23  17:00  Eliteserien   Matchweek 3  Sun  Away      W  3  0
# 3  2023-04-29  18:00  Eliteserien   Matchweek 4  Sat  Home      D  2  2
# 4  2023-05-03  18:00  Eliteserien  Matchweek 18  Wed  Home      W  2  0
# ..        ...    ...          ...           ...  ...   ...    ... .. ..
# 25 2023-10-28  18:00  Eliteserien  Matchweek 26  Sat  Away      L  1  6
# 26 2023-11-06  19:00  Eliteserien  Matchweek 27  Mon  Home      L  0  3
# 27 2023-11-12  17:00  Eliteserien  Matchweek 28  Sun  Away      L  0  1
# 28 2023-11-26  17:00  Eliteserien  Matchweek 29  Sun  Home      L  0  4
# 29 2023-12-03  17:00  Eliteserien  Matchweek 30  Sun  Away      L  1  4
#
#         opponent  ...  dist  pk pkatt season       team venue_code opp_code  \
# 0   Sarpsborg 08  ...   NaN   0     0   2023  BodoGlimt          0       13
# 1         Stabæk  ...   NaN   0     1   2023  BodoGlimt          1       14
# 2       Aalesund  ...   NaN   0     0   2023  BodoGlimt          0        0
# 3          Brann  ...   NaN   0     0   2023  BodoGlimt          1        2
# 4            Odd  ...   NaN   0     0   2023  BodoGlimt          1       10
# ..           ...  ...   ...  ..   ...    ...        ...        ...      ...
# 25     Haugesund  ...   NaN   0     0   2023   Aalesund          0        4
# 26    Sandefjord  ...   NaN   0     0   2023   Aalesund          1       12
# 27    Bodø/Glimt  ...   NaN   0     0   2023   Aalesund          0        1
# 28        Viking  ...   NaN   0     0   2023   Aalesund          1       17
# 29           Odd  ...   NaN   0     0   2023   Aalesund          0       10
#
#     hour  day_code  target
# 0     17         0       1
# 1     17         6       1
# 2     17         6       1
# 3     18         5       0
# 4     18         2       1
# ..   ...       ...     ...
# 25    18         5       0
# 26    19         0       0
# 27    17         6       0
# 28    17         6       0
# 29    17         6       0
#
# [480 rows x 29 columns]

# %% [markdown]
# The predictors we use in this model is venue, opposition, time of day and which day the match was played on.

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
error = accuracy_score(test["target"], preds)

# %% [markdown]
# This model receives an accuracy score of 0.58. This means that whatever the model predicted, 58% of the time that thing happened, but lets dig deeper.

# %%
error
# Out:
# 0.58125

# %% [markdown]
# To get a better understanding, we create a dataframe that combine our actual values and predicted values

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %% [markdown]
# From this crosstab we can see that our model 257 times our model predicted a draw or a loss it was correct, and 176 times it was wrong. The model predicted a win 25 times when the result was a draw or a loss, and it predicted a win 22 times when the result was a win.
# Our goal with this project is to predict wins, we need to revise the way we score the model, as accuracy scores also include predictions for draw or loss.

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          257  25
# 1          176  22

# %% [markdown]
# The prediction score will show us how often the result was a win when a win was predicted. Every time the model predicted a win, the team only won 47% of the time.

# %%
precision_score(test["target"], preds)
# Out:
# np.float64(0.46808510638297873)

# %% [markdown]
# We can try to improve the model by adding rolling stats for each team. We start by splitting our matches dataframe into teams.

# %%
grouped_matches = matches.groupby("team")

# %% [markdown]
# This is what one group looks like, this is all of Brann's matches. The goal of the rolling stats is that if we are on matchweek 4, how well did brann do in the previous 3 matchweeks. This will add a factor of form, which can play a key part in football.

# %%
group = grouped_matches.get_group("Brann").sort_values("date")

# %%
group
# Out:
#          date   time         comp         round  day venue result gf ga  \
# 0  2021-05-09  18:00  Eliteserien   Matchweek 1  Sun  Away      L  1  3
# 1  2021-05-12  20:00  Eliteserien   Matchweek 2  Wed  Home      L  0  3
# 2  2021-05-16  20:00  Eliteserien   Matchweek 3  Sun  Away      L  0  4
# 3  2021-05-20  20:30  Eliteserien  Matchweek 14  Thu  Away      L  2  3
# 4  2021-05-24  18:00  Eliteserien   Matchweek 4  Mon  Home      L  1  2
# 5  2021-05-27  18:00  Eliteserien   Matchweek 5  Thu  Away      L  0  2
# 6  2021-05-30  18:00  Eliteserien   Matchweek 6  Sun  Home      W  3  0
# 7  2021-06-13  18:00  Eliteserien   Matchweek 7  Sun  Away      D  0  0
# 8  2021-06-20  18:00  Eliteserien   Matchweek 8  Sun  Home      L  1  3
# 9  2021-06-24  18:00  Eliteserien   Matchweek 9  Thu  Away      L  0  1
# 10 2021-06-30  20:00  Eliteserien  Matchweek 10  Wed  Home      D  1  1
# 11 2021-07-05  19:00  Eliteserien  Matchweek 11  Mon  Away      L  2  3
# 12 2021-07-10  20:00  Eliteserien  Matchweek 12  Sat  Home      D  1  1
# 13 2021-07-18  18:00  Eliteserien  Matchweek 13  Sun  Home      D  1  1
# 14 2021-08-15  20:00  Eliteserien  Matchweek 15  Sun  Home      W  3  2
# 15 2021-08-21  20:00  Eliteserien  Matchweek 16  Sat  Away      L  1  3
# 16 2021-08-28  20:00  Eliteserien  Matchweek 17  Sat  Home      L  1  3
# 17 2021-09-11  18:00  Eliteserien  Matchweek 18  Sat  Away      W  3  2
# 18 2021-09-19  20:00  Eliteserien  Matchweek 19  Sun  Away      D  1  1
# 19 2021-09-26  18:00  Eliteserien  Matchweek 20  Sun  Home      W  3  1
# 20 2021-10-03  18:00  Eliteserien  Matchweek 21  Sun  Away      D  1  1
# 21 2021-10-17  17:00  Eliteserien  Matchweek 22  Sun  Home      D  1  1
# 22 2021-10-24  19:00  Eliteserien  Matchweek 23  Sun  Away      D  3  3
# 23 2021-10-28  18:00  Eliteserien  Matchweek 24  Thu  Home      L  0  2
# 24 2021-10-31  20:00  Eliteserien  Matchweek 25  Sun  Away      L  0  1
# 25 2021-11-06  18:00  Eliteserien  Matchweek 26  Sat  Home      D  2  2
# 26 2021-11-21  17:00  Eliteserien  Matchweek 27  Sun  Away      D  2  2
# 27 2021-11-28  19:00  Eliteserien  Matchweek 28  Sun  Home      L  0  1
# 28 2021-12-05  17:00  Eliteserien  Matchweek 29  Sun  Away      D  2  2
# 29 2021-12-12  17:00  Eliteserien  Matchweek 30  Sun  Home      W  2  1
# 0  2023-04-10  19:15  Eliteserien   Matchweek 1  Mon  Home      W  3  0
# 1  2023-04-16  17:00  Eliteserien   Matchweek 2  Sun  Away      L  0  2
# 2  2023-04-22  18:00  Eliteserien   Matchweek 3  Sat  Home      W  3  1
# 3  2023-04-29  18:00  Eliteserien   Matchweek 4  Sat  Away      D  2  2
# 4  2023-05-03  18:00  Eliteserien  Matchweek 18  Wed  Away      W  2  0
# 5  2023-05-08  19:00  Eliteserien   Matchweek 5  Mon  Home      D  0  0
# 6  2023-05-13  17:00  Eliteserien   Matchweek 6  Sat  Away      L  1  2
# 7  2023-05-16  18:00  Eliteserien   Matchweek 7  Tue  Home      W  4  1
# 8  2023-05-29  17:00  Eliteserien   Matchweek 8  Mon  Home      W  3  1
# 9  2023-06-04  17:00  Eliteserien   Matchweek 9  Sun  Away      W  3  1
# 10 2023-06-11  19:15  Eliteserien  Matchweek 10  Sun  Home      D  2  2
# 11 2023-06-24  18:00  Eliteserien  Matchweek 11  Sat  Away      L  1  3
# 12 2023-07-02  17:00  Eliteserien  Matchweek 12  Sun  Home      W  2  1
# 13 2023-07-09  19:15  Eliteserien  Matchweek 13  Sun  Away      L  0  2
# 14 2023-07-16  19:15  Eliteserien  Matchweek 14  Sun  Home      W  1  0
# 15 2023-07-23  17:00  Eliteserien  Matchweek 15  Sun  Away      L  1  3
# 16 2023-07-30  17:00  Eliteserien  Matchweek 16  Sun  Home      L  0  2
# 17 2023-08-06  17:00  Eliteserien  Matchweek 17  Sun  Away      W  2  0
# 18 2023-08-20  17:00  Eliteserien  Matchweek 19  Sun  Home      W  5  1
# 19 2023-09-03  17:00  Eliteserien  Matchweek 21  Sun  Home      W  1  0
# 20 2023-09-17  17:00  Eliteserien  Matchweek 22  Sun  Away      W  1  0
# 21 2023-09-24  19:15  Eliteserien  Matchweek 23  Sun  Home      W  2  1
# 22 2023-10-01  15:00  Eliteserien  Matchweek 20  Sun  Away      W  2  0
# 23 2023-10-08  19:15  Eliteserien  Matchweek 24  Sun  Away      W  2  1
# 24 2023-10-21  18:00  Eliteserien  Matchweek 25  Sat  Home      W  3  2
# 25 2023-10-29  17:00  Eliteserien  Matchweek 26  Sun  Away      D  1  1
# 26 2023-11-05  17:00  Eliteserien  Matchweek 27  Sun  Home      W  2  1
# 27 2023-11-11  18:00  Eliteserien  Matchweek 28  Sat  Away      W  2  0
# 28 2023-11-26  17:00  Eliteserien  Matchweek 29  Sun  Home      W  4  2
# 29 2023-12-03  17:00  Eliteserien  Matchweek 30  Sun  Away      L  0  3
#
#         opponent  ...  dist  pk pkatt season   team venue_code opp_code  hour  \
# 0         Viking  ...   NaN   0     0   2021  Brann          0       17    18
# 1      Vålerenga  ...   NaN   0     0   2021  Brann          1       18    20
# 2          Molde  ...   NaN   0     0   2021  Brann          0        9    20
# 3      Rosenborg  ...   NaN   0     0   2021  Brann          0       11    20
# 4     Bodø/Glimt  ...   NaN   0     0   2021  Brann          1        1    18
# 5         Stabæk  ...   NaN   0     1   2021  Brann          0       14    18
# 6   Strømsgodset  ...   NaN   0     1   2021  Brann          1       15    18
# 7   Sarpsborg 08  ...   NaN   0     0   2021  Brann          0       13    18
# 8            Odd  ...   NaN   0     0   2021  Brann          1       10    18
# 9      Haugesund  ...   NaN   0     0   2021  Brann          0        4    18
# 10    Lillestrøm  ...   NaN   0     0   2021  Brann          1        7    20
# 11  Kristiansund  ...   NaN   0     0   2021  Brann          0        6    19
# 12        Tromsø  ...   NaN   0     0   2021  Brann          1       16    20
# 13     Mjøndalen  ...   NaN   0     0   2021  Brann          1        8    18
# 14    Sandefjord  ...   NaN   1     1   2021  Brann          1       12    20
# 15  Strømsgodset  ...   NaN   0     0   2021  Brann          0       15    20
# 16     Haugesund  ...   NaN   0     1   2021  Brann          1        4    20
# 17    Lillestrøm  ...   NaN   0     0   2021  Brann          0        7    18
# 18        Tromsø  ...   NaN   0     0   2021  Brann          0       16    20
# 19  Kristiansund  ...   NaN   0     0   2021  Brann          1        6    18
# 20     Mjøndalen  ...   NaN   0     0   2021  Brann          0        8    18
# 21        Stabæk  ...   NaN   0     0   2021  Brann          1       14    17
# 22           Odd  ...   NaN   0     0   2021  Brann          0       10    19
# 23        Viking  ...   NaN   0     0   2021  Brann          1       17    18
# 24     Vålerenga  ...   NaN   0     0   2021  Brann          0       18    20
# 25     Rosenborg  ...   NaN   0     0   2021  Brann          1       11    18
# 26    Sandefjord  ...   NaN   0     0   2021  Brann          0       12    17
# 27         Molde  ...   NaN   0     0   2021  Brann          1        9    19
# 28    Bodø/Glimt  ...   NaN   0     0   2021  Brann          0        1    17
# 29  Sarpsborg 08  ...   NaN   0     0   2021  Brann          1       13    17
# 0      Haugesund  ...   NaN   1     1   2023  Brann          1        4    19
# 1            Odd  ...   NaN   0     0   2023  Brann          0       10    17
# 2      Vålerenga  ...   NaN   1     1   2023  Brann          1       18    18
# 3     Bodø/Glimt  ...   NaN   0     0   2023  Brann          0        1    18
# 4      Rosenborg  ...   NaN   0     0   2023  Brann          0       11    18
# 5     Sandefjord  ...   NaN   0     0   2023  Brann          1       12    19
# 6   Sarpsborg 08  ...   NaN   0     0   2023  Brann          0       13    17
# 7         Stabæk  ...   NaN   0     0   2023  Brann          1       14    18
# 8      Rosenborg  ...   NaN   0     0   2023  Brann          1       11    17
# 9       Aalesund  ...   NaN   1     1   2023  Brann          0        0    17
# 10    Lillestrøm  ...   NaN   1     2   2023  Brann          1        7    19
# 11        Viking  ...   NaN   0     0   2023  Brann          0       17    18
# 12        HamKam  ...   NaN   1     1   2023  Brann          1        3    17
# 13         Molde  ...   NaN   0     0   2023  Brann          0        9    19
# 14  Strømsgodset  ...   NaN   0     0   2023  Brann          1       15    19
# 15        Tromsø  ...   NaN   0     0   2023  Brann          0       16    17
# 16        Viking  ...   NaN   0     0   2023  Brann          1       17    17
# 17        HamKam  ...   NaN   0     0   2023  Brann          0        3    17
# 18      Aalesund  ...   NaN   0     0   2023  Brann          1        0    17
# 19  Sarpsborg 08  ...   NaN   1     2   2023  Brann          1       13    17
# 20        Stabæk  ...   NaN   0     0   2023  Brann          0       14    17
# 21        Tromsø  ...   NaN   0     0   2023  Brann          1       16    19
# 22    Lillestrøm  ...   NaN   1     1   2023  Brann          0        7    15
# 23     Vålerenga  ...   NaN   0     0   2023  Brann          0       18    19
# 24         Molde  ...   NaN   0     1   2023  Brann          1        9    18
# 25    Sandefjord  ...   NaN   0     0   2023  Brann          0       12    17
# 26           Odd  ...   NaN   0     0   2023  Brann          1       10    17
# 27     Haugesund  ...   NaN   1     1   2023  Brann          0        4    18
# 28    Bodø/Glimt  ...   NaN   0     0   2023  Brann          1        1    17
# 29  Strømsgodset  ...   NaN   0     0   2023  Brann          0       15    17
#
#     day_code  target
# 0          6       0
# 1          2       0
# 2          6       0
# 3          3       0
# 4          0       0
# 5          3       0
# 6          6       1
# 7          6       0
# 8          6       0
# 9          3       0
# 10         2       0
# 11         0       0
# 12         5       0
# 13         6       0
# 14         6       1
# 15         5       0
# 16         5       0
# 17         5       1
# 18         6       0
# 19         6       1
# 20         6       0
# 21         6       0
# 22         6       0
# 23         3       0
# 24         6       0
# 25         5       0
# 26         6       0
# 27         6       0
# 28         6       0
# 29         6       1
# 0          0       1
# 1          6       0
# 2          5       1
# 3          5       0
# 4          2       1
# 5          0       0
# 6          5       0
# 7          1       1
# 8          0       1
# 9          6       1
# 10         6       0
# 11         5       0
# 12         6       1
# 13         6       0
# 14         6       1
# 15         6       0
# 16         6       0
# 17         6       1
# 18         6       1
# 19         6       1
# 20         6       1
# 21         6       1
# 22         6       1
# 23         6       1
# 24         5       1
# 25         6       0
# 26         6       1
# 27         5       1
# 28         6       1
# 29         6       0
#
# [60 rows x 29 columns]

# %% [markdown]
# We create a function which takes a group, a set of columns that we will use for our rolling stats, and finally compute and add columns for our rolling averages.

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %% [markdown]
# We want the rolling averages of goals for, goals against, shots, shots on target, penalty kick and penalty kick attempts.

# %%
cols = ["gf", "ga", "sh", "sot", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %% [markdown]
# This is what the dataframe looks like for Brann with the rolling averages.

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time         comp         round  day venue result gf ga  \
# 3  2021-05-20  20:30  Eliteserien  Matchweek 14  Thu  Away      L  2  3
# 4  2021-05-24  18:00  Eliteserien   Matchweek 4  Mon  Home      L  1  2
# 5  2021-05-27  18:00  Eliteserien   Matchweek 5  Thu  Away      L  0  2
# 6  2021-05-30  18:00  Eliteserien   Matchweek 6  Sun  Home      W  3  0
# 7  2021-06-13  18:00  Eliteserien   Matchweek 7  Sun  Away      D  0  0
# 8  2021-06-20  18:00  Eliteserien   Matchweek 8  Sun  Home      L  1  3
# 9  2021-06-24  18:00  Eliteserien   Matchweek 9  Thu  Away      L  0  1
# 10 2021-06-30  20:00  Eliteserien  Matchweek 10  Wed  Home      D  1  1
# 11 2021-07-05  19:00  Eliteserien  Matchweek 11  Mon  Away      L  2  3
# 12 2021-07-10  20:00  Eliteserien  Matchweek 12  Sat  Home      D  1  1
# 13 2021-07-18  18:00  Eliteserien  Matchweek 13  Sun  Home      D  1  1
# 14 2021-08-15  20:00  Eliteserien  Matchweek 15  Sun  Home      W  3  2
# 15 2021-08-21  20:00  Eliteserien  Matchweek 16  Sat  Away      L  1  3
# 16 2021-08-28  20:00  Eliteserien  Matchweek 17  Sat  Home      L  1  3
# 17 2021-09-11  18:00  Eliteserien  Matchweek 18  Sat  Away      W  3  2
# 18 2021-09-19  20:00  Eliteserien  Matchweek 19  Sun  Away      D  1  1
# 19 2021-09-26  18:00  Eliteserien  Matchweek 20  Sun  Home      W  3  1
# 20 2021-10-03  18:00  Eliteserien  Matchweek 21  Sun  Away      D  1  1
# 21 2021-10-17  17:00  Eliteserien  Matchweek 22  Sun  Home      D  1  1
# 22 2021-10-24  19:00  Eliteserien  Matchweek 23  Sun  Away      D  3  3
# 23 2021-10-28  18:00  Eliteserien  Matchweek 24  Thu  Home      L  0  2
# 24 2021-10-31  20:00  Eliteserien  Matchweek 25  Sun  Away      L  0  1
# 25 2021-11-06  18:00  Eliteserien  Matchweek 26  Sat  Home      D  2  2
# 26 2021-11-21  17:00  Eliteserien  Matchweek 27  Sun  Away      D  2  2
# 27 2021-11-28  19:00  Eliteserien  Matchweek 28  Sun  Home      L  0  1
# 28 2021-12-05  17:00  Eliteserien  Matchweek 29  Sun  Away      D  2  2
# 29 2021-12-12  17:00  Eliteserien  Matchweek 30  Sun  Home      W  2  1
# 0  2023-04-10  19:15  Eliteserien   Matchweek 1  Mon  Home      W  3  0
# 1  2023-04-16  17:00  Eliteserien   Matchweek 2  Sun  Away      L  0  2
# 2  2023-04-22  18:00  Eliteserien   Matchweek 3  Sat  Home      W  3  1
# 3  2023-04-29  18:00  Eliteserien   Matchweek 4  Sat  Away      D  2  2
# 4  2023-05-03  18:00  Eliteserien  Matchweek 18  Wed  Away      W  2  0
# 5  2023-05-08  19:00  Eliteserien   Matchweek 5  Mon  Home      D  0  0
# 6  2023-05-13  17:00  Eliteserien   Matchweek 6  Sat  Away      L  1  2
# 7  2023-05-16  18:00  Eliteserien   Matchweek 7  Tue  Home      W  4  1
# 8  2023-05-29  17:00  Eliteserien   Matchweek 8  Mon  Home      W  3  1
# 9  2023-06-04  17:00  Eliteserien   Matchweek 9  Sun  Away      W  3  1
# 10 2023-06-11  19:15  Eliteserien  Matchweek 10  Sun  Home      D  2  2
# 11 2023-06-24  18:00  Eliteserien  Matchweek 11  Sat  Away      L  1  3
# 12 2023-07-02  17:00  Eliteserien  Matchweek 12  Sun  Home      W  2  1
# 13 2023-07-09  19:15  Eliteserien  Matchweek 13  Sun  Away      L  0  2
# 14 2023-07-16  19:15  Eliteserien  Matchweek 14  Sun  Home      W  1  0
# 15 2023-07-23  17:00  Eliteserien  Matchweek 15  Sun  Away      L  1  3
# 16 2023-07-30  17:00  Eliteserien  Matchweek 16  Sun  Home      L  0  2
# 17 2023-08-06  17:00  Eliteserien  Matchweek 17  Sun  Away      W  2  0
# 18 2023-08-20  17:00  Eliteserien  Matchweek 19  Sun  Home      W  5  1
# 19 2023-09-03  17:00  Eliteserien  Matchweek 21  Sun  Home      W  1  0
# 20 2023-09-17  17:00  Eliteserien  Matchweek 22  Sun  Away      W  1  0
# 21 2023-09-24  19:15  Eliteserien  Matchweek 23  Sun  Home      W  2  1
# 22 2023-10-01  15:00  Eliteserien  Matchweek 20  Sun  Away      W  2  0
# 23 2023-10-08  19:15  Eliteserien  Matchweek 24  Sun  Away      W  2  1
# 24 2023-10-21  18:00  Eliteserien  Matchweek 25  Sat  Home      W  3  2
# 25 2023-10-29  17:00  Eliteserien  Matchweek 26  Sun  Away      D  1  1
# 26 2023-11-05  17:00  Eliteserien  Matchweek 27  Sun  Home      W  2  1
# 27 2023-11-11  18:00  Eliteserien  Matchweek 28  Sat  Away      W  2  0
# 28 2023-11-26  17:00  Eliteserien  Matchweek 29  Sun  Home      W  4  2
# 29 2023-12-03  17:00  Eliteserien  Matchweek 30  Sun  Away      L  0  3
#
#         opponent  ...  opp_code  hour day_code target gf_rolling ga_rolling  \
# 3      Rosenborg  ...        11    20        3      0   0.333333   3.333333
# 4     Bodø/Glimt  ...         1    18        0      0   0.666667   3.333333
# 5         Stabæk  ...        14    18        3      0   1.000000   3.000000
# 6   Strømsgodset  ...        15    18        6      1   1.000000   2.333333
# 7   Sarpsborg 08  ...        13    18        6      0   1.333333   1.333333
# 8            Odd  ...        10    18        6      0   1.000000   0.666667
# 9      Haugesund  ...         4    18        3      0   1.333333   1.000000
# 10    Lillestrøm  ...         7    20        2      0   0.333333   1.333333
# 11  Kristiansund  ...         6    19        0      0   0.666667   1.666667
# 12        Tromsø  ...        16    20        5      0   1.000000   1.666667
# 13     Mjøndalen  ...         8    18        6      0   1.333333   1.666667
# 14    Sandefjord  ...        12    20        6      1   1.333333   1.666667
# 15  Strømsgodset  ...        15    20        5      0   1.666667   1.333333
# 16     Haugesund  ...         4    20        5      0   1.666667   2.000000
# 17    Lillestrøm  ...         7    18        5      1   1.666667   2.666667
# 18        Tromsø  ...        16    20        6      0   1.666667   2.666667
# 19  Kristiansund  ...         6    18        6      1   1.666667   2.000000
# 20     Mjøndalen  ...         8    18        6      0   2.333333   1.333333
# 21        Stabæk  ...        14    17        6      0   1.666667   1.000000
# 22           Odd  ...        10    19        6      0   1.666667   1.000000
# 23        Viking  ...        17    18        3      0   1.666667   1.666667
# 24     Vålerenga  ...        18    20        6      0   1.333333   2.000000
# 25     Rosenborg  ...        11    18        5      0   1.000000   2.000000
# 26    Sandefjord  ...        12    17        6      0   0.666667   1.666667
# 27         Molde  ...         9    19        6      0   1.333333   1.666667
# 28    Bodø/Glimt  ...         1    17        6      0   1.333333   1.666667
# 29  Sarpsborg 08  ...        13    17        6      1   1.333333   1.666667
# 0      Haugesund  ...         4    19        0      1   1.333333   1.333333
# 1            Odd  ...        10    17        6      0   2.333333   1.000000
# 2      Vålerenga  ...        18    18        5      1   1.666667   1.000000
# 3     Bodø/Glimt  ...         1    18        5      0   2.000000   1.000000
# 4      Rosenborg  ...        11    18        2      1   1.666667   1.666667
# 5     Sandefjord  ...        12    19        0      0   2.333333   1.000000
# 6   Sarpsborg 08  ...        13    17        5      0   1.333333   0.666667
# 7         Stabæk  ...        14    18        1      1   1.000000   0.666667
# 8      Rosenborg  ...        11    17        0      1   1.666667   1.000000
# 9       Aalesund  ...         0    17        6      1   2.666667   1.333333
# 10    Lillestrøm  ...         7    19        6      0   3.333333   1.000000
# 11        Viking  ...        17    18        5      0   2.666667   1.333333
# 12        HamKam  ...         3    17        6      1   2.000000   2.000000
# 13         Molde  ...         9    19        6      0   1.666667   2.000000
# 14  Strømsgodset  ...        15    19        6      1   1.000000   2.000000
# 15        Tromsø  ...        16    17        6      0   1.000000   1.000000
# 16        Viking  ...        17    17        6      0   0.666667   1.666667
# 17        HamKam  ...         3    17        6      1   0.666667   1.666667
# 18      Aalesund  ...         0    17        6      1   1.000000   1.666667
# 19  Sarpsborg 08  ...        13    17        6      1   2.333333   1.000000
# 20        Stabæk  ...        14    17        6      1   2.666667   0.333333
# 21        Tromsø  ...        16    19        6      1   2.333333   0.333333
# 22    Lillestrøm  ...         7    15        6      1   1.333333   0.333333
# 23     Vålerenga  ...        18    19        6      1   1.666667   0.333333
# 24         Molde  ...         9    18        5      1   2.000000   0.666667
# 25    Sandefjord  ...        12    17        6      0   2.333333   1.000000
# 26           Odd  ...        10    17        6      1   2.000000   1.333333
# 27     Haugesund  ...         4    18        5      1   2.000000   1.333333
# 28    Bodø/Glimt  ...         1    17        6      1   1.666667   0.666667
# 29  Strømsgodset  ...        15    17        6      0   2.666667   1.000000
#
#    sh_rolling  sot_rolling  pk_rolling  pkatt_rolling
# 3   13.000000     3.666667    0.000000       0.000000
# 4   13.333333     4.333333    0.000000       0.000000
# 5   15.333333     5.333333    0.000000       0.000000
# 6   12.666667     6.000000    0.000000       0.333333
# 7   13.666667     5.666667    0.000000       0.666667
# 8   10.000000     3.666667    0.000000       0.666667
# 9   12.666667     3.000000    0.000000       0.333333
# 10   9.000000     2.333333    0.000000       0.000000
# 11  11.666667     3.333333    0.000000       0.000000
# 12  10.333333     3.666667    0.000000       0.000000
# 13  13.000000     4.333333    0.000000       0.000000
# 14  15.333333     5.000000    0.000000       0.000000
# 15  13.666667     4.666667    0.333333       0.333333
# 16  13.666667     5.333333    0.333333       0.333333
# 17  11.666667     5.000000    0.333333       0.666667
# 18  14.000000     6.333333    0.000000       0.333333
# 19  15.666667     5.666667    0.000000       0.333333
# 20  17.333333     6.000000    0.000000       0.000000
# 21  20.000000     5.666667    0.000000       0.000000
# 22  19.000000     6.000000    0.000000       0.000000
# 23  18.666667     6.000000    0.000000       0.000000
# 24  18.333333     4.666667    0.000000       0.000000
# 25  17.666667     4.666667    0.000000       0.000000
# 26  19.333333     4.000000    0.000000       0.000000
# 27  17.333333     6.333333    0.000000       0.000000
# 28  18.000000     5.666667    0.000000       0.000000
# 29  15.000000     6.000000    0.000000       0.000000
# 0   15.000000     4.666667    0.000000       0.000000
# 1   15.666667     6.333333    0.333333       0.333333
# 2   17.000000     5.000000    0.333333       0.333333
# 3   18.666667     5.333333    0.666667       0.666667
# 4   14.333333     3.666667    0.333333       0.333333
# 5   14.333333     5.333333    0.333333       0.333333
# 6   15.000000     4.666667    0.000000       0.000000
# 7   19.666667     6.000000    0.000000       0.000000
# 8   17.666667     5.333333    0.000000       0.000000
# 9   14.000000     5.666667    0.000000       0.000000
# 10  14.666667     5.666667    0.333333       0.333333
# 11  17.333333     6.333333    0.666667       1.000000
# 12  18.333333     5.000000    0.666667       1.000000
# 13  18.000000     4.666667    0.666667       1.000000
# 14  14.666667     3.000000    0.333333       0.333333
# 15  15.000000     4.666667    0.333333       0.333333
# 16  11.333333     3.666667    0.000000       0.000000
# 17  13.333333     3.666667    0.000000       0.000000
# 18  16.666667     4.333333    0.000000       0.000000
# 19  20.000000     7.000000    0.000000       0.000000
# 20  19.333333     7.666667    0.333333       0.666667
# 21  14.666667     7.000000    0.333333       0.666667
# 22  11.000000     4.000000    0.333333       0.666667
# 23  13.333333     6.666667    0.333333       0.333333
# 24  12.000000     5.333333    0.333333       0.333333
# 25  14.666667     6.666667    0.333333       0.666667
# 26  14.000000     4.666667    0.000000       0.333333
# 27  18.000000     5.333333    0.000000       0.333333
# 28  15.666667     4.333333    0.333333       0.333333
# 29  14.000000     4.666667    0.333333       0.333333
#
# [57 rows x 35 columns]

# %% [markdown]
# Now that we have confirmed that the code works, we will apply this to all teams. We apply the rolling_averages function to every team in the matches dataframe.

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %% [markdown]
# This is what the new dataframe looks like

# %%
matches_rolling
# Out:
#                   date   time         comp         round  day venue result gf  \
# team
# Aalesund 3  2022-04-23  16:00  Eliteserien   Matchweek 4  Sat  Away      W  3
#          4  2022-04-28  20:00  Eliteserien  Matchweek 15  Thu  Away      L  0
#          5  2022-05-08  20:00  Eliteserien   Matchweek 5  Sun  Away      D  0
#          6  2022-05-16  18:00  Eliteserien   Matchweek 6  Mon  Home      L  0
#          7  2022-05-22  18:00  Eliteserien   Matchweek 7  Sun  Away      W  2
# ...                ...    ...          ...           ...  ...   ...    ... ..
# Viking   25 2023-10-29  17:00  Eliteserien  Matchweek 26  Sun  Away      L  0
#          26 2023-11-04  18:00  Eliteserien  Matchweek 27  Sat  Away      L  0
#          27 2023-11-12  17:00  Eliteserien  Matchweek 28  Sun  Home      W  2
#          28 2023-11-26  17:00  Eliteserien  Matchweek 29  Sun  Away      W  4
#          29 2023-12-03  17:00  Eliteserien  Matchweek 30  Sun  Home      L  1
#
#             ga      opponent  ...  opp_code  hour day_code target gf_rolling  \
# team                          ...
# Aalesund 3   2           Odd  ...        10    16        5      1   1.000000
#          4   2    Lillestrøm  ...         7    20        3      0   1.666667
#          5   0        HamKam  ...         3    20        6      0   1.666667
#          6   2         Molde  ...         9    18        0      0   1.000000
#          7   1  Sarpsborg 08  ...        13    18        6      1   0.000000
# ...         ..           ...  ...       ...   ...      ...    ...        ...
# Viking   25  1  Strømsgodset  ...        15    17        6      0   1.333333
#          26  3        HamKam  ...         3    18        5      0   1.333333
#          27  1  Sarpsborg 08  ...        13    17        6      1   1.000000
#          28  0      Aalesund  ...         0    17        6      1   0.666667
#          29  5     Rosenborg  ...        11    17        6      0   2.000000
#
#             ga_rolling sh_rolling  sot_rolling  pk_rolling  pkatt_rolling
# team
# Aalesund 3    1.000000  11.666667     3.333333         0.0            0.0
#          4    1.666667   8.666667     4.000000         0.0            0.0
#          5    2.000000  11.000000     4.333333         0.0            0.0
#          6    1.333333  10.666667     4.000000         0.0            0.0
#          7    1.333333  12.333333     2.333333         0.0            0.0
# ...                ...        ...          ...         ...            ...
# Viking   25   3.000000  10.666667     3.666667         0.0            0.0
#          26   2.000000  13.333333     5.333333         0.0            0.0
#          27   2.666667  20.333333     7.333333         0.0            0.0
#          28   1.666667  16.333333     6.333333         0.0            0.0
#          29   1.333333  14.666667     6.000000         0.0            0.0
#
# [1383 rows x 35 columns]

# %% [markdown]
# We dont want the new index that was created, as it makes the dataframe harder to work with. We also want the index to be unique for each row.

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time         comp         round  day venue result gf ga  \
# 0    2022-04-23  16:00  Eliteserien   Matchweek 4  Sat  Away      W  3  2
# 1    2022-04-28  20:00  Eliteserien  Matchweek 15  Thu  Away      L  0  2
# 2    2022-05-08  20:00  Eliteserien   Matchweek 5  Sun  Away      D  0  0
# 3    2022-05-16  18:00  Eliteserien   Matchweek 6  Mon  Home      L  0  2
# 4    2022-05-22  18:00  Eliteserien   Matchweek 7  Sun  Away      W  2  1
# ...         ...    ...          ...           ...  ...   ...    ... .. ..
# 1378 2023-10-29  17:00  Eliteserien  Matchweek 26  Sun  Away      L  0  1
# 1379 2023-11-04  18:00  Eliteserien  Matchweek 27  Sat  Away      L  0  3
# 1380 2023-11-12  17:00  Eliteserien  Matchweek 28  Sun  Home      W  2  1
# 1381 2023-11-26  17:00  Eliteserien  Matchweek 29  Sun  Away      W  4  0
# 1382 2023-12-03  17:00  Eliteserien  Matchweek 30  Sun  Home      L  1  5
#
#           opponent  ...  opp_code  hour day_code target gf_rolling ga_rolling  \
# 0              Odd  ...        10    16        5      1   1.000000   1.000000
# 1       Lillestrøm  ...         7    20        3      0   1.666667   1.666667
# 2           HamKam  ...         3    20        6      0   1.666667   2.000000
# 3            Molde  ...         9    18        0      0   1.000000   1.333333
# 4     Sarpsborg 08  ...        13    18        6      1   0.000000   1.333333
# ...            ...  ...       ...   ...      ...    ...        ...        ...
# 1378  Strømsgodset  ...        15    17        6      0   1.333333   3.000000
# 1379        HamKam  ...         3    18        5      0   1.333333   2.000000
# 1380  Sarpsborg 08  ...        13    17        6      1   1.000000   2.666667
# 1381      Aalesund  ...         0    17        6      1   0.666667   1.666667
# 1382     Rosenborg  ...        11    17        6      0   2.000000   1.333333
#
#      sh_rolling  sot_rolling  pk_rolling  pkatt_rolling
# 0     11.666667     3.333333         0.0            0.0
# 1      8.666667     4.000000         0.0            0.0
# 2     11.000000     4.333333         0.0            0.0
# 3     10.666667     4.000000         0.0            0.0
# 4     12.333333     2.333333         0.0            0.0
# ...         ...          ...         ...            ...
# 1378  10.666667     3.666667         0.0            0.0
# 1379  13.333333     5.333333         0.0            0.0
# 1380  20.333333     7.333333         0.0            0.0
# 1381  16.333333     6.333333         0.0            0.0
# 1382  14.666667     6.000000         0.0            0.0
#
# [1383 rows x 35 columns]

# %% [markdown]
# We create a function to make our predictions for future work. This way if we want to create some changes we can call this function on the new dataframe without typing everything for each change.

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    error_accuracy = accuracy_score(test["target"], preds)
    return combined, error, error_accuracy

# %% [markdown]
# We run the function on the matches_rolling dataframe with the same predictors + the new columns we created earlier.

# %%
combined, error, error_accuracy = make_predictions(matches_rolling, predictors + new_cols)

# %% [markdown]
# The precision score improved slightly, but the results are not great. for every time the model predicted a win, 50% of the time the result was a win.

# %%
error
# Out:
# np.float64(0.4976958525345622)

# %% [markdown]
# The accuracy has also slightly improved

# %%
error_accuracy
# Out:
# 0.6025236593059937

# %% [markdown]
# The model has 465 true negative predictions and 269 false negative predictions, while having 109 false positive predictions and 108 true positive predictions

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0    1
# actual
# 0          465  109
# 1          269  108

# %% [markdown]
# When this model was tested on English Premier League matches it received a precision score of 0.625, so I'm a little disappointed with 0.497 for this project. For future work we will look into the parameters set for the random forest classifier to look for improvement, and perhaps try other non-linear models to see if they can perform better.
#
# The not-so-great result compared to the Premier League dataset might also be because the top teams in England are more consistent, while in Norwegian football, as Tore-André Flo once said, anyone can beat anyone.
